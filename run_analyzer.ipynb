# %%
from Run import *
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
run_storage_folder = Run.read_runs_folder('./example_data/')
#run_storage_folder = Run.read_runs_folder('./takeout/')
for r in run_storage_folder:
    print(run_storage_folder[r].getStartTime())
    print(run_storage_folder[r].getMaximumHeartRate())
    print(r)
    #print(run_storage_folder[r]._Values)
    #time.strftime("%m/%d/%Y %H:%M:%S", ts)
    #print(run_storage_folder[r].getValues())
    #for i in run_storage_folder[r].getValues():
    #    print(i)
# Out:
# 2018-02-10T09:03:55.000Z
# 178.0
# 2018-02-10T09:03:55.000Z
# 2018-02-26T09:04:00.000Z
# 148.0
# 2018-02-26T09:04:00.000Z
# 2018-02-18T09:47:36.000Z
# 175.0
# 2018-02-18T09:47:36.000Z
# 2018-02-12T07:50:50.000Z
# 108.0
# 2018-02-12T07:50:50.000Z

# %%
run_storage_folder['2018-02-10T09:03:55.000Z'].getStartTime()
#run_storage_folder['2018-02-10T09:03:55.000Z']._Values
# Out:
# '2018-02-10T09:03:55.000Z'

# %%
data = run_storage_folder['2018-02-10T09:03:55.000Z'].getValues()
print(data[0,2])
print(data[1,2])
print(data[2,2])
print(data[0:,1])
print(data[0:,2])
print(data[0:,3])
#print(data)
#[Timevalue, Heartrate,  AltitudeMeters, LatitudeDegrees, LongitudeDegrees]
np.shape(data)
plt.subplot(1,3,1)
plt.title('heartrate')
plt.ylabel('beats per minute')
plt.plot(data[0:,1])

plt.subplot(1,3,2)
plt.title('altitude meters')
plt.ylabel('meter')
plt.plot(data[0:,2])


plt.subplot(1,3,3)
plt.title('orientation')
plt.ylabel('latitude')
plt.xlabel('longitude')
plt.plot(data[0:,3],data[0:,4])


plt.tight_layout()
plt.savefig('Run.pdf', dpi=600, bbox_inches='tight',transparent=1)
plt.show()
# Out:
# 0
# 91.44580078125
# 91.44580078125
# [70.0 71.0 71.0 ... 96.0 96.0 95.0]
# [0 91.44580078125 91.44580078125 ... 1.0 1.0 1.0]
# [0 51.247314453125 51.247314453125 ... 51.247806549072266
#  51.247806549072266 51.247806549072266]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-44a50127f8a7> in <module>()
#      24 plt.ylabel('latitude')
#      25 plt.xlabel('longitude')
# ---> 26 plt.plot(data[0:,3],data[0:][1])
#      27
#      28
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
#time.strftime("%m/%d/%Y %H:%M:%S", ts)
fig, ax1 = plt.subplots()
times = range(7)
co2 = [250,265,272,260,300,320,389]
Temp = [14.1, 15.5, 16.3, 18.1, 17.3, 19.1, 20.2]
ax1.plot(times, co2, 'b--')
ax2 = ax1.twinx()
ax2.plot(times, Temp, 'r')
plt.title("Temperature and CO2 versus time")
ax1.set_ylabel("Concentration [CO2]" )
ax2.set_ylabel("Temperature [degC]" )
plt.xlabel(" Time ( decade )")
plt.show()

# %%
n_bins = 10
x = np.random.randn(1000, 3)

fig, axes = plt.subplots(nrows=2, ncols=2)
ax0, ax1, ax2, ax3 = axes.flatten()

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, density=True, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, density=True, histtype='bar', stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show()
