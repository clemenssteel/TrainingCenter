# %%
from Run import *
#import os
#from glob import glob

# %%
run_storage_folder = read_runs_folder('./example_data/')
for r in run_storage_folder:
    print(run_storage_folder[r]._StartTime)
    print(run_storage_folder[r].getStartTime())
    print(r)
    #print(run_storage_folder[r]._Values)
# Out:
# StartTime 2018-02-10T09:03:55.000Z
# Running
# Total Time 5482.672
# Calories 1310.0
# Stored AverageHeartRate 144.32717967464814
# Stored MaximumHeartRate 178.0
# StartTime 2018-02-26T07:25:53.000Z
# Running
# Total Time 7.0
# Calories 4.71258020401001
# Stored AverageHeartRate 109.5
# Stored MaximumHeartRate 110.0
# StartTime 2018-02-26T07:26:00.000Z
# Running
# Total Time 60.0
# Calories 14.471373558044434
# Stored AverageHeartRate 118.62295081967213
# Stored MaximumHeartRate 132.0
# StartTime 2018-02-26T07:27:00.000Z
# Running
# Total Time 60.0
# Calories 14.471372604370117
# Stored AverageHeartRate 142.672131147541
# Stored MaximumHeartRate 146.0
# StartTime 2018-02-26T07:28:00.000Z
# Running
# Total Time 60.0
# Calories 14.471372604370117
# Stored AverageHeartRate 147.2295081967213
# Stored MaximumHeartRate 149.0
# StartTime 2018-02-26T07:29:00.000Z
# Running
# Total Time 60.0
# Calories 14.471370697021484
# Stored AverageHeartRate 148.45901639344262
# ...

# %%
run_storage_folder['2018-02-10T09:03:55.000Z'].getStartTime()
run_storage_folder['2018-02-10T09:03:55.000Z']._Values
# Out:
# [('2018-02-10T09:03:55.000Z', '70.0', '', '', ''),
#  ('2018-02-10T09:03:56.000Z',
#   '71.0',
#   '91.44580078125',
#   '51.247314453125',
#   '6.8177103996276855'),
#  ('2018-02-10T09:03:57.000Z',
#   '71.0',
#   '91.44580078125',
#   '51.247314453125',
#   '6.8177103996276855'),
#  ('2018-02-10T09:03:58.000Z',
#   '71.0',
#   '91.44580078125',
#   '51.247314453125',
#   '6.8177103996276855'),
#  ('2018-02-10T09:03:59.000Z',
#   '70.0',
#   '91.44580078125',
#   '51.247314453125',
#   '6.8177103996276855'),
#  ('2018-02-10T09:04:00.000Z',
#   '71.0',
#   '89.39404296875',
#   '51.24732208251953',
#   '6.817647933959961'),
#  ('2018-02-10T09:04:01.000Z',
#   '71.0',
#   '88.54017639160156',
#   '51.24730682373047',
#   '6.817639350891113'),
#  ('2018-02-10T09:04:02.000Z',
#   '71.0',
#   '87.64956665039062',
#   '51.24728012084961',
#   '6.817543983459473'),
#  ('2018-02-10T09:04:03.000Z',
#   '71.0',
#   '87.50137329101562',
#   '51.24726104736328',
#   '6.8175506591796875'),
# ...
